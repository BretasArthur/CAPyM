# 2016-02-01             0
# 2016-03-01             0
# 2016-04-01             0
# 2016-05-01             0
# 2016-06-01             0
# 2016-07-01             0
# 2016-08-01             0
# 2016-09-01             0
# 2016-10-01             0
# 2016-11-01             0
# 2016-12-01             0

# %%
petr4 = yf.Ticker("PETR4.SA")
hist_p4 = petr4.history(start="2015-10-01", end = "2020-10-01", interval = "1mo")
hist_p4.describe()
# Out:
#             Open       High        Low      Close        Volume  Dividends  \
# count  61.000000  61.000000  61.000000  61.000000  6.100000e+01  73.000000
# mean   17.549148  19.228333  15.950937  17.629106  1.193730e+09   0.025483
# std     7.083679   7.285790   6.615408   6.867059  4.367899e+08   0.102051
# min     4.397310   4.898270   3.822134   4.490080  6.462295e+08   0.000000
# 25%    12.681695  14.063973  11.837484  12.663140  9.239898e+08   0.000000
# 50%    17.696456  18.688618  14.936012  17.607796  1.114261e+09   0.000000
# 75%    24.606286  26.140544  21.519573  23.725742  1.333739e+09   0.000000
# max    30.177769  31.237690  28.335720  29.775162  2.916373e+09   0.716563
#
#        Stock Splits
# count          73.0
# mean            0.0
# std             0.0
# min             0.0
# 25%             0.0
# 50%             0.0
# 75%             0.0
# max             0.0

# %%
hist_p4.dropna(axis=0, subset=['Close'], inplace=True)
hist_p4.describe()
# Out:
#             Open       High        Low      Close        Volume  Dividends  \
# count  61.000000  61.000000  61.000000  61.000000  6.100000e+01       61.0
# mean   17.549148  19.228333  15.950937  17.629106  1.193730e+09        0.0
# std     7.083679   7.285790   6.615408   6.867059  4.367899e+08        0.0
# min     4.397310   4.898270   3.822134   4.490080  6.462295e+08        0.0
# 25%    12.681695  14.063973  11.837484  12.663140  9.239898e+08        0.0
# 50%    17.696456  18.688618  14.936012  17.607796  1.114261e+09        0.0
# 75%    24.606286  26.140544  21.519573  23.725742  1.333739e+09        0.0
# max    30.177769  31.237690  28.335720  29.775162  2.916373e+09        0.0
#
#        Stock Splits
# count          61.0
# mean            0.0
# std             0.0
# min             0.0
# 25%             0.0
# 50%             0.0
# 75%             0.0
# max             0.0

# %%
hist_p4.head(15)
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2015-10-01   6.781506   8.414262   6.401148   7.375236  1.329618e+09
# 2015-11-01   7.152587   8.024627   6.707290   7.115479  1.637778e+09
# 2015-12-01   7.115479   7.579330   6.048621   6.215607  9.200237e+08
# 2016-01-01   6.215607   6.521749   3.822134   4.490080  1.378894e+09
# 2016-02-01   4.397310   4.898270   3.822135   4.768392  1.263760e+09
# 2016-03-01   4.926101   8.349324   4.731283   7.709209  2.035058e+09
# 2016-04-01   7.755594   9.777986   6.994878   9.490397  7.633115e+08
# 2016-05-01   9.508952   9.740877   7.458729   7.458729  1.189975e+09
# 2016-06-01   7.505114   9.045100   7.291742   8.738958  1.183668e+09
# 2016-07-01   8.794621  11.364357   8.302939  11.011830  1.120804e+09
# 2016-08-01  11.067491  12.273504  10.297498  11.920978  1.134965e+09
# 2016-09-01  12.032302  13.256869  11.837484  12.588923  1.015943e+09
# 2016-10-01  12.681695  17.153222  12.635310  16.411060  1.132745e+09
# 2016-11-01  16.587321  16.587321  12.366275  14.843241  1.299425e+09
# 2016-12-01  14.843241  15.167937  12.997113  13.794937  7.850627e+08
#
#             Dividends  Stock Splits
# Date
# 2015-10-01        0.0             0
# 2015-11-01        0.0             0
# 2015-12-01        0.0             0
# 2016-01-01        0.0             0
# 2016-02-01        0.0             0
# 2016-03-01        0.0             0
# 2016-04-01        0.0             0
# 2016-05-01        0.0             0
# 2016-06-01        0.0             0
# 2016-07-01        0.0             0
# 2016-08-01        0.0             0
# 2016-09-01        0.0             0
# 2016-10-01        0.0             0
# 2016-11-01        0.0             0
# 2016-12-01        0.0             0

# %%
prices = pd.concat([hist_b11['Close'], hist_p4['Close']], axis=1)
prices.columns = ['Petrobras', 'iBovespa']
prices.describe()
# Out:
#         Petrobras   iBovespa
# count   61.000000  61.000000
# mean    75.418210  17.629106
# std     19.271638   6.867059
# min     39.189999   4.490080
# 25%     60.930000  12.663140
# 50%     74.120003  17.607796
# 75%     92.010002  23.725742
# max    111.230003  29.775162

# %%
prices.head()
# Out:
#             Petrobras  iBovespa
# Date
# 2015-10-01  44.400002  7.375236
# 2015-11-01  43.700001  7.115479
# 2015-12-01  42.130001  6.215607
# 2016-01-01  39.189999  4.490080
# 2016-02-01  41.450001  4.768392

# %%
mon_returns = prices.pct_change()
mon_returns.dropna(axis=0, inplace= True)
mon_returns.head()
# Out:
#             Petrobras  iBovespa
# Date
# 2015-11-01  -0.015766 -0.035220
# 2015-12-01  -0.035927 -0.126467
# 2016-01-01  -0.069784 -0.277612
# 2016-02-01   0.057668  0.061984
# 2016-03-01   0.173462  0.616732

# %%
mon_returns.plot(
    title = 'Petrobrás and iBovespa Montly Returns - from november 2015 to octuber 2020',
    figsize = [15,8],
    style = ['limegreen', 'royalblue'],
    grid = True)

# %%
x = mon_returns['Petrobras']
y = mon_returns['iBovespa']

model = stats.linregress(x, y)

model
# Out:
# LinregressResult(slope=1.8045052749507953, intercept=0.0003698831510926953, rvalue=0.8311131332024037, pvalue=2.0631476311016372e-16, stderr=0.15854025128029536)

# %%
print("Beta =", model[0])
# Out:
# Beta = 1.8045052749507953

# %% [markdown]
# The beta is not exactally the same as indicated in yahoo finance's page...but it's close. Some tests are necessary, maybe they used the S&P500 as to make it, maybe some adjustments are needed
